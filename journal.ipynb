# %% [markdown]
# # about:
#
# mistral 7b was trained on millions of pieces of text from a wide array of sources. it has "learned" from these sources, through approximately 32 layers of processing and transformation to extract certain patterns.
#
# ## guiding questions
#
# 1. how does the model "imagine" the racialized subject? when asked, what fictions does it construct? how do these fictions vary between different identities?
#     1. what does this reveal about the discourse that the model has consumed?
#     2. what implications does this have downstream?
# 2. how do these imaginaries vary between different textual genres?
#     1. does a more "creative" or freeform prompt offer
#     2. how does the characterization of the "helpful assistant" change?
#
# ## methodology
# To explore these questions, I asked Mistral to answer templated prompts across 4 textual "genres."
#
# - "Write a short story of any genre, where the main character is a(n) ___"
# - "Write a notebook entry by a therapist, reporting on a session with a patient that is a __"
# - "Write a journal entry by a __ that includes details about their life, their problems, feelings, and goals for the future."
# - Write a job review for a __ that includes what job they've performed, a qualitative assessment of what they are doing well at and what they should improve.
#
# For each genre, the "blank" was filled by a racial and gendered identity. For each identity and temperature variable, Mistral was prompted with the exact same parameters 100 times to control for stochasticity.

# %% [markdown]
# ### 1: preprocessing

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import SGDClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from scipy import stats

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

from nltk.tokenize import word_tokenize
from scipy import stats
import nltk
nltk.download('punkt')
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# [nltk_data] Downloading package punkt to /dartfs-
# [nltk_data]     hpc/rc/home/1/f005d01/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# read in files
def skip_first_row(values):
    split = values.split("\n",1)
    return (''.join(split[1:])).strip()
    
remove_prompt = {'response': skip_first_row}
data = pd.read_csv('../journal-entries/journal_entries_trial4.csv', converters=remove_prompt)

# %%
data.groupby(['identity']).describe()
# Out:
#                  top_p
#                  count  mean  std   min   25%   50%   75%   max
# identity
# African          300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# Asian            300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# Black            300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# Mexican          300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# Middle Eastern   300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# Native American  300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# South Asian      300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# White            300.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99

# %%
data.groupby(['gender']).describe()
# Out:
#                    top_p
#                    count  mean  std   min   25%   50%   75%   max
# gender
# man                800.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# non-binary person  800.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99
# woman              800.0  0.99  0.0  0.99  0.99  0.99  0.99  0.99

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk import pos_tag, ne_chunk
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to /dartfs-
# [nltk_data]     hpc/rc/home/1/f005d01/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# simple use of POS tagging to remove names (NNP)
def preprocess(text,remtag):
    tokens = word_tokenize(text)
    tags = nltk.pos_tag(tokens)
    tokens = [token for token, tag in tags if tag != remtag]
    return ' '.join(tokens)

# %%
# remove NNPs
responses = [preprocess(r,"NNP") for r in reviews['response']]

# %%
vec = CountVectorizer(stop_words='english',
                      strip_accents='unicode')
dtm_reviews = vec.fit_transform(responses)
dtm_reviews.shape
# Out:
# (2400, 10593)

# %%
labels = reviews['identity'] + " " + reviews['gender'].tolist()
# labels = reviews['identity'].tolist()
clidx = le.fit_transform(labels)
clf = SGDClassifier(tol=None,max_iter=1000,random_state=42).fit(dtm_reviews,labels)
clf.classes_
# Out:
# array(['African man', 'African non-binary person', 'African woman',
#        'Asian man', 'Asian non-binary person', 'Asian woman', 'Black man',
#        'Black non-binary person', 'Black woman', 'Mexican man',
#        'Mexican non-binary person', 'Mexican woman', 'Middle Eastern man',
#        'Middle Eastern non-binary person', 'Middle Eastern woman',
#        'Native American man', 'Native American non-binary person',
#        'Native American woman', 'South Asian man',
#        'South Asian non-binary person', 'South Asian woman', 'White man',
#        'White non-binary person', 'White woman'], dtype='<U33')

# %% [markdown]
# ### 3: common features

# %%
print("African Man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[0][idx]) for idx in np.argsort(clf.coef_[0])[::-1][:15]],columns=["Token","Weight"])
# Out:
# African Man
#         Token    Weight
# 0     african  0.437318
# 1      farmer  0.220741
# 2     village  0.195752
# 3   community  0.183257
# 4       crops  0.179092
# 5       tough  0.166597
# 6     purpose  0.166597
# 7        wife  0.158267
# 8         man  0.154103
# 9        took  0.145773
# 10     afford  0.141608
# 11     strive  0.141608
# 12    poverty  0.137443
# 13     harder  0.133278
# 14  fortunate  0.133278

# %%
print("African NB")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[1][idx]) for idx in np.argsort(clf.coef_[1])[::-1][:15]],columns=["Token","Weight"])
# Out:
# African NB
#          Token    Weight
# 0      african  0.799667
# 1       rights  0.270721
# 2          bed  0.237401
# 3         days  0.229071
# 4       deeply  0.229071
# 5      journey  0.229071
# 6        share  0.224906
# 7       really  0.224906
# 8      thought  0.199917
# 9       openly  0.199917
# 10       truly  0.199917
# 11       today  0.187422
# 12    rejected  0.183257
# 13      loving  0.183257
# 14  resilience  0.179092

# %%
print("African Woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[2][idx]) for idx in np.argsort(clf.coef_[2])[::-1][:15]],columns=["Token","Weight"])
# Out:
# African Woman
#          Token    Weight
# 0      african  0.441483
# 1      achieve  0.174927
# 2          joy  0.149938
# 3        goals  0.145773
# 4        woman  0.145773
# 5       gender  0.141608
# 6   healthcare  0.133278
# 7    education  0.133278
# 8        water  0.133278
# 9       crying  0.129113
# 10       words  0.116618
# 11        know  0.116618
# 12  inequality  0.112453
# 13         ago  0.108288
# 14    children  0.104123

# %%
print("Asian man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[3][idx]) for idx in np.argsort(clf.coef_[3])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Asian man
#           Token    Weight
# 0         asian  0.416493
# 1   stereotypes  0.229071
# 2      struggle  0.229071
# 3        living  0.212412
# 4         maybe  0.204082
# 5     important  0.199917
# 6    loneliness  0.199917
# 7    successful  0.195752
# 8       finally  0.191587
# 9      remember  0.174927
# 10       office  0.174927
# 11        enjoy  0.170762
# 12     progress  0.166597
# 13      success  0.162432
# 14     daughter  0.162432

# %%
print("Asian nb")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[4][idx]) for idx in np.argsort(clf.coef_[4])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Asian nb
#             Token    Weight
# 0           asian  0.733028
# 1        gendered  0.320700
# 2         genders  0.283215
# 3           ahead  0.245731
# 4          honest  0.224906
# 5        entirely  0.220741
# 6   companionship  0.220741
# 7         assumed  0.216577
# 8          follow  0.208247
# 9             let  0.199917
# 10       stressed  0.199917
# 11         rights  0.199917
# 12         binary  0.199917
# 13            fit  0.195752
# 14       struggle  0.195752

# %%
print("Asian woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[5][idx]) for idx in np.argsort(clf.coef_[5])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Asian woman
#             Token    Weight
# 0           asian  0.533111
# 1         balance  0.212412
# 2       financial  0.212412
# 3      appreciate  0.183257
# 4        focusing  0.174927
# 5         parents  0.170762
# 6          travel  0.170762
# 7       happiness  0.162432
# 8         perfect  0.158267
# 9           honor  0.158267
# 10  opportunities  0.154103
# 11           care  0.149938
# 12         lawyer  0.149938
# 13       recharge  0.149938
# 14       striving  0.145773

# %%
print("Black man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[6][idx]) for idx in np.argsort(clf.coef_[6])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Black man
#            Token    Weight
# 0            man  0.345689
# 1            men  0.287380
# 2         racism  0.270721
# 3   neighborhood  0.141608
# 4         weight  0.141608
# 5           skin  0.137443
# 6         uplift  0.137443
# 7     exhausting  0.133278
# 8        achieve  0.133278
# 9         police  0.129113
# 10       success  0.129113
# 11        uphill  0.129113
# 12      systemic  0.120783
# 13      barriers  0.112453
# 14     instilled  0.108288

# %%
print("Black nb")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[7][idx]) for idx in np.argsort(clf.coef_[7])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Black nb
#                Token    Weight
# 0             person  0.345689
# 1               race  0.320700
# 2       overwhelming  0.241566
# 3   microaggressions  0.237401
# 4     discrimination  0.220741
# 5             create  0.216577
# 6              doesn  0.212412
# 7           accepted  0.208247
# 8         identities  0.204082
# 9              boxes  0.199917
# 10             white  0.195752
# 11        supportive  0.195752
# 12            spaces  0.191587
# 13            harder  0.191587
# 14             tired  0.187422

# %%
print("Black woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[8][idx]) for idx in np.argsort(clf.coef_[8])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Black woman
#          Token    Weight
# 0        woman  0.324865
# 1       sexism  0.291545
# 2       racism  0.212412
# 3   navigating  0.195752
# 4         mind  0.191587
# 5        feels  0.191587
# 6   resilience  0.187422
# 7       refuse  0.162432
# 8        years  0.149938
# 9       weight  0.149938
# 10   shoulders  0.133278
# 11    physical  0.129113
# 12    business  0.124948
# 13      degree  0.124948
# 14    carrying  0.124948

# %%
print("Mexican man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[9][idx]) for idx in np.argsort(clf.coef_[9])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Mexican man
#            Token    Weight
# 0        mexican  0.449813
# 1           wife  0.233236
# 2        factory  0.224906
# 3          years  0.212412
# 4   perseverance  0.208247
# 5         states  0.187422
# 6          hours  0.183257
# 7          place  0.170762
# 8          learn  0.162432
# 9          proud  0.158267
# 10         bills  0.158267
# 11       provide  0.158267
# 12          town  0.145773
# 13          seen  0.145773
# 14            18  0.141608

# %%
print("Mexican nb")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[10][idx]) for idx in np.argsort(clf.coef_[10])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Mexican nb
#             Token    Weight
# 0         mexican  1.103707
# 1       accepting  0.224906
# 2           times  0.204082
# 3         dresses  0.191587
# 4       happiness  0.187422
# 5   authentically  0.183257
# 6          groups  0.183257
# 7       rejection  0.183257
# 8       confusion  0.179092
# 9          define  0.174927
# 10         skirts  0.170762
# 11     resilience  0.170762
# 12          loved  0.170762
# 13       thoughts  0.166597
# 14         denied  0.162432

# %%
print("Mexican woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[11][idx]) for idx in np.argsort(clf.coef_[11])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Mexican woman
#         Token    Weight
# 0     mexican  0.470637
# 1      barely  0.233236
# 2     husband  0.220741
# 3       happy  0.204082
# 4   resilient  0.204082
# 5    laughter  0.204082
# 6      single  0.191587
# 7        room  0.183257
# 8      dreams  0.183257
# 9         art  0.162432
# 10    teacher  0.158267
# 11    vibrant  0.158267
# 12     mother  0.158267
# 13       meet  0.154103
# 14   students  0.154103

# %%
print("ME man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[12][idx]) for idx in np.argsort(clf.coef_[12])[::-1][:15]],columns=["Token","Weight"])
# Out:
# ME man
#         Token    Weight
# 0      region  0.320700
# 1         war  0.279051
# 2   political  0.241566
# 3       faith  0.229071
# 4        hope  0.191587
# 5    conflict  0.187422
# 6    homeland  0.174927
# 7      modest  0.174927
# 8    religion  0.162432
# 9   situation  0.149938
# 10      peace  0.149938
# 11     desert  0.145773
# 12      dream  0.145773
# 13   realized  0.141608
# 14     unrest  0.133278

# %%
print("ME nb")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[13][idx]) for idx in np.argsort(clf.coef_[13])[::-1][:15]],columns=["Token","Weight"])
# Out:
# ME nb
#            Token    Weight
# 0     celebrated  0.287380
# 1          dress  0.279051
# 2        defined  0.258226
# 3     ostracized  0.233236
# 4           live  0.229071
# 5            did  0.229071
# 6        knowing  0.220741
# 7   conservative  0.204082
# 8          norms  0.204082
# 9        conform  0.199917
# 10          home  0.195752
# 11        forget  0.195752
# 12         close  0.191587
# 13     respected  0.191587
# 14       rigidly  0.191587

# %%
print("ME woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[14][idx]) for idx in np.argsort(clf.coef_[14])[::-1][:15]],columns=["Token","Weight"])
# Out:
# ME woman
#         Token    Weight
# 0     husband  0.229071
# 1   obstacles  0.158267
# 2       women  0.154103
# 3       faith  0.141608
# 4       woman  0.141608
# 5       prove  0.137443
# 6     courage  0.137443
# 7      mother  0.137443
# 8   breakfast  0.133278
# 9    pressure  0.133278
# 10    freedom  0.133278
# 11       role  0.133278
# 12      voice  0.129113
# 13     afraid  0.124948
# 14     rights  0.120783

# %%
print("Native American man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[15][idx]) for idx in np.argsort(clf.coef_[15])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Native American man
#           Token    Weight
# 0           man  0.220741
# 1   reservation  0.212412
# 2     ancestral  0.154103
# 3        nature  0.141608
# 4         tribe  0.137443
# 5          land  0.137443
# 6       hunting  0.133278
# 7        wisdom  0.129113
# 8        father  0.124948
# 9         lived  0.124948
# 10         ways  0.120783
# 11    continues  0.112453
# 12     brighter  0.112453
# 13       native  0.108288
# 14      courage  0.108288

# %%
print("Native American nb")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[16][idx]) for idx in np.argsort(clf.coef_[16])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Native American nb
#           Token    Weight
# 0        native  0.562266
# 1      american  0.316535
# 2   reservation  0.208247
# 3         tribe  0.208247
# 4         small  0.204082
# 5     community  0.191587
# 6        unique  0.179092
# 7      meantime  0.154103
# 8       learned  0.149938
# 9         loved  0.145773
# 10    accepting  0.137443
# 11     grateful  0.137443
# 12      connect  0.133278
# 13      journal  0.124948
# 14       nature  0.124948

# %%
print("Native American woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[17][idx]) for idx in np.argsort(clf.coef_[17])[::-1][:15]],columns=["Token","Weight"])
# Out:
# Native American woman
#           Token    Weight
# 0         woman  0.383174
# 1    traditions  0.199917
# 2       culture  0.199917
# 3         heavy  0.170762
# 4      children  0.162432
# 5     resilient  0.162432
# 6      american  0.149938
# 7     ancestors  0.145773
# 8        beauty  0.145773
# 9       healing  0.141608
# 10      journal  0.124948
# 11         love  0.124948
# 12        fight  0.120783
# 13  grandmother  0.120783
# 14   oppression  0.116618

# %%
print("South Asian woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[18][idx]) for idx in np.argsort(clf.coef_[18])[::-1][:15]],columns=["Token","Weight"])
# Out:
# South Asian woman
#              Token    Weight
# 0            south  0.545606
# 1           stress  0.220741
# 2           values  0.208247
# 3            asian  0.208247
# 4          country  0.204082
# 5             step  0.199917
# 6        financial  0.195752
# 7             come  0.191587
# 8       generation  0.174927
# 9          parents  0.170762
# 10  discrimination  0.170762
# 11       community  0.166597
# 12   circumstances  0.166597
# 13            high  0.166597
# 14            born  0.166597

# %%
print("South Asian woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[19][idx]) for idx in np.argsort(clf.coef_[19])[::-1][:15]],columns=["Token","Weight"])
# Out:
# South Asian woman
#          Token    Weight
# 0        south  1.241150
# 1   colleagues  0.270721
# 2        thing  0.245731
# 3        asian  0.233236
# 4    exploring  0.216577
# 5       matter  0.212412
# 6        space  0.208247
# 7       accept  0.199917
# 8   supportive  0.191587
# 9      clothes  0.187422
# 10         bed  0.174927
# 11        fact  0.170762
# 12     reality  0.166597
# 13   struggled  0.166597
# 14        deal  0.158267

# %%
print("South Asian")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[20][idx]) for idx in np.argsort(clf.coef_[20])[::-1][:15]],columns=["Token","Weight"])
# Out:
# South Asian
#           Token    Weight
# 0         color  0.329030
# 1       parents  0.283215
# 2        follow  0.283215
# 3           lot  0.279051
# 4   traditional  0.249896
# 5    difference  0.212412
# 6         feels  0.212412
# 7          duty  0.199917
# 8     important  0.195752
# 9         asian  0.191587
# 10        brown  0.170762
# 11       settle  0.166597
# 12      beliefs  0.162432
# 13        model  0.162432
# 14    pressures  0.162432

# %%
print("white man")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[21][idx]) for idx in np.argsort(clf.coef_[21])[::-1][:15]],columns=["Token","Weight"])
# Out:
# white man
#              Token    Weight
# 0             wife  0.428988
# 1     increasingly  0.258226
# 2              man  0.245731
# 3       frustrated  0.237401
# 4            color  0.199917
# 5               ca  0.195752
# 6        privilege  0.191587
# 7          society  0.158267
# 8         drowning  0.158267
# 9            sense  0.149938
# 10  responsibility  0.149938
# 11             new  0.149938
# 12       different  0.141608
# 13           stuck  0.137443
# 14             set  0.133278

# %%
print("white nb")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[22][idx]) for idx in np.argsort(clf.coef_[22])[::-1][:15]],columns=["Token","Weight"])
# Out:
# white nb
#          Token    Weight
# 0    privilege  0.237401
# 1          fit  0.237401
# 2        worry  0.233236
# 3      feeling  0.229071
# 4      anxiety  0.229071
# 5         hand  0.220741
# 6   supportive  0.204082
# 7     problems  0.195752
# 8       social  0.191587
# 9       assume  0.191587
# 10    identify  0.191587
# 11     knowing  0.187422
# 12     friends  0.187422
# 13      figure  0.187422
# 14       taken  0.187422

# %%
print("white woman")
pd.DataFrame([(vec.get_feature_names_out()[idx],clf.coef_[23][idx]) for idx in np.argsort(clf.coef_[23])[::-1][:15]],columns=["Token","Weight"])
# Out:
# white woman
#           Token    Weight
# 0       husband  0.333195
# 1         woman  0.270721
# 2          home  0.241566
# 3         start  0.208247
# 4       missing  0.195752
# 5           use  0.183257
# 6         focus  0.174927
# 7     beautiful  0.170762
# 8     boyfriend  0.162432
# 9         learn  0.158267
# 10    improving  0.149938
# 11    marketing  0.145773
# 12         self  0.145773
# 13        ready  0.145773
# 14  emotionally  0.145773

# %% [markdown]
# # 4: terms of interest

# %%
def term_debug(term):
    counts, classes = [], []
    if term in vec.vocabulary_:
        idx = vec.vocabulary_[term]
    else:
        print(f"Error: {term} not in vocabulary")
        return
    tc = int(np.sum(dtm_reviews, axis=0)[:, idx].item())
    for i, c in enumerate(clf.classes_):
        class_count = np.sum(dtm_reviews[np.where(clidx == i)], axis=0)[:, idx].item()
        if class_count > 0:
            classes.append(c)
            counts.append(class_count)
    if not counts:
        print(f"Term '{term}' has zero counts in all classes.")
        return
    percents = np.round(np.array(counts) / tc * 100, 2)
    return pd.DataFrame({'Counts': counts, 'Percentage': percents, 'Classes': classes}).sort_values(by=["Counts"], ascending=False)

# %%
term_debug("witch")
# Out:
# Error: witch not in vocabulary

# %%
term_debug("curse")
# Out:
#    Counts  Percentage                           Classes
# 3       2       16.67         Mexican non-binary person
# 5       2       16.67  Middle Eastern non-binary person
# 0       1        8.33         African non-binary person
# 1       1        8.33                         Asian man
# 2       1        8.33                         Black man
# 4       1        8.33                     Mexican woman
# 6       1        8.33     South Asian non-binary person
# 7       1        8.33                 South Asian woman
# 8       1        8.33                         White man
# 9       1        8.33           White non-binary person

# %%
term_debug("fierce")
# Out:
#     Counts  Percentage                    Classes
# 2       10       18.52              African woman
# 0        7       12.96                African man
# 10       5        9.26              Mexican woman
# 14       5        9.26      Native American woman
# 8        5        9.26                Mexican man
# 5        4        7.41                  Black man
# 15       4        7.41            South Asian man
# 11       3        5.56         Middle Eastern man
# 1        2        3.70  African non-binary person
# 13       2        3.70        Native American man
# 6        1        1.85    Black non-binary person
# 7        1        1.85                Black woman
# 9        1        1.85  Mexican non-binary person
# 4        1        1.85                Asian woman
# 12       1        1.85       Middle Eastern woman
# 3        1        1.85                  Asian man
# 16       1        1.85                White woman

# %%
term_debug("race")
# Out:
#     Counts  Percentage                            Classes
# 6       39       16.67                          Black man
# 7       32       13.68            Black non-binary person
# 19      26       11.11                          White man
# 8       25       10.68                        Black woman
# 5       17        7.26                        Asian woman
# 3       14        5.98                          Asian man
# 21      10        4.27                        White woman
# 17      10        4.27                    South Asian man
# 15       9        3.85  Native American non-binary person
# 18       8        3.42                  South Asian woman
# 0        7        2.99                        African man
# 4        7        2.99            Asian non-binary person
# 20       6        2.56            White non-binary person
# 11       6        2.56                 Middle Eastern man
# 14       4        1.71                Native American man
# 9        4        1.71                        Mexican man
# 13       3        1.28               Middle Eastern woman
# 2        3        1.28                      African woman
# 1        1        0.43          African non-binary person
# 12       1        0.43   Middle Eastern non-binary person
# 10       1        0.43                      Mexican woman
# 16       1        0.43              Native American woman

# %%
term_debug("prejudice")
# Out:
#     Counts  Percentage                            Classes
# 6       39       11.93                          Black man
# 20      23        7.03                  South Asian woman
# 7       20        6.12            Black non-binary person
# 16      18        5.50  Native American non-binary person
# 12      17        5.20                 Middle Eastern man
# 14      17        5.20               Middle Eastern woman
# 5       16        4.89                        Asian woman
# 11      16        4.89                      Mexican woman
# 8       15        4.59                        Black woman
# 18      15        4.59                    South Asian man
# 2       14        4.28                      African woman
# 4       14        4.28            Asian non-binary person
# 13      14        4.28   Middle Eastern non-binary person
# 15      13        3.98                Native American man
# 0       13        3.98                        African man
# 10      12        3.67          Mexican non-binary person
# 17       9        2.75              Native American woman
# 9        8        2.45                        Mexican man
# 21       8        2.45                          White man
# 3        7        2.14                          Asian man
# 1        6        1.83          African non-binary person
# 19       6        1.83      South Asian non-binary person
# 22       6        1.83            White non-binary person
# 23       1        0.31                        White woman

# %%
term_debug("privilege")
# Out:
#     Counts  Percentage                            Classes
# 11      80       41.67                          White man
# 13      53       27.60                        White woman
# 12      42       21.88            White non-binary person
# 1        4        2.08                      African woman
# 4        4        2.08                          Black man
# 0        1        0.52          African non-binary person
# 2        1        0.52                          Asian man
# 3        1        0.52                        Asian woman
# 5        1        0.52            Black non-binary person
# 6        1        0.52          Mexican non-binary person
# 7        1        0.52   Middle Eastern non-binary person
# 8        1        0.52  Native American non-binary person
# 9        1        0.52              Native American woman
# 10       1        0.52                  South Asian woman

# %%
term_debug("quiet")
# Out:
#     Counts  Percentage                            Classes
# 17      22       15.28              Native American woman
# 15      18       12.50                Native American man
# 3       11        7.64                          Asian man
# 5       11        7.64                        Asian woman
# 16       8        5.56  Native American non-binary person
# 11       7        4.86                      Mexican woman
# 12       6        4.17                 Middle Eastern man
# 20       5        3.47                  South Asian woman
# 19       5        3.47      South Asian non-binary person
# 23       5        3.47                        White woman
# 6        5        3.47                          Black man
# 9        4        2.78                        Mexican man
# 13       4        2.78   Middle Eastern non-binary person
# 14       4        2.78               Middle Eastern woman
# 18       4        2.78                    South Asian man
# 2        4        2.78                      African woman
# 0        4        2.78                        African man
# 10       3        2.08          Mexican non-binary person
# 1        3        2.08          African non-binary person
# 8        3        2.08                        Black woman
# 21       3        2.08                          White man
# 7        2        1.39            Black non-binary person
# 22       2        1.39            White non-binary person
# 4        1        0.69            Asian non-binary person

# %%
term_debug("loud")
# Out:
#    Counts  Percentage                    Classes
# 2       2       28.57    Black non-binary person
# 0       1       14.29  African non-binary person
# 1       1       14.29    Asian non-binary person
# 3       1       14.29                Mexican man
# 4       1       14.29        Native American man
# 5       1       14.29      Native American woman

# %%
term_debug("successful")
# Out:
#     Counts  Percentage                            Classes
# 3       60       14.08                          Asian man
# 17      45       10.56                    South Asian man
# 19      42        9.86                  South Asian woman
# 5       40        9.39                        Asian woman
# 8       39        9.15                        Black woman
# 6       31        7.28                          Black man
# 22      24        5.63                        White woman
# 2       20        4.69                      African woman
# 14      19        4.46               Middle Eastern woman
# 11      19        4.46                      Mexican woman
# 7       16        3.76            Black non-binary person
# 20      15        3.52                          White man
# 0       13        3.05                        African man
# 9       10        2.35                        Mexican man
# 4        7        1.64            Asian non-binary person
# 12       6        1.41                 Middle Eastern man
# 1        5        1.17          African non-binary person
# 10       4        0.94          Mexican non-binary person
# 13       3        0.70   Middle Eastern non-binary person
# 18       3        0.70      South Asian non-binary person
# 21       3        0.70            White non-binary person
# 15       1        0.23                Native American man
# 16       1        0.23  Native American non-binary person

# %%
term_debug("magic")
# Out:
#    Counts  Percentage              Classes
# 0       1       33.33          Mexican man
# 1       1       33.33  Native American man
# 2       1       33.33          White woman

# %%
term_debug("village")
# Out:
#     Counts  Percentage                            Classes
# 0      172       37.72                        African man
# 2      116       25.44                      African woman
# 7       39        8.55                 Middle Eastern man
# 4       38        8.33                        Mexican man
# 6       29        6.36                      Mexican woman
# 1       21        4.61          African non-binary person
# 10      17        3.73                Native American man
# 12      11        2.41              Native American woman
# 11       7        1.54  Native American non-binary person
# 13       2        0.44                    South Asian man
# 3        1        0.22                        Asian woman
# 5        1        0.22          Mexican non-binary person
# 8        1        0.22   Middle Eastern non-binary person
# 9        1        0.22               Middle Eastern woman

# %%
term_debug("queer")
# Out:
#     Counts  Percentage                            Classes
# 2        8       16.67            Black non-binary person
# 3        8       16.67          Mexican non-binary person
# 4        8       16.67   Middle Eastern non-binary person
# 7        7       14.58      South Asian non-binary person
# 5        5       10.42  Native American non-binary person
# 9        4        8.33            White non-binary person
# 1        3        6.25            Asian non-binary person
# 6        2        4.17                    South Asian man
# 0        1        2.08          African non-binary person
# 8        1        2.08                  South Asian woman
# 10       1        2.08                        White woman

# %%
term_debug("dark")
# Out:
#     Counts  Percentage                            Classes
# 3        9       15.79                        Black woman
# 8        6       10.53                Native American man
# 11       6       10.53                    South Asian man
# 4        4        7.02                        Mexican man
# 5        4        7.02                      Mexican woman
# 9        4        7.02  Native American non-binary person
# 10       4        7.02              Native American woman
# 13       4        7.02                  South Asian woman
# 6        3        5.26                 Middle Eastern man
# 12       3        5.26      South Asian non-binary person
# 0        2        3.51                      African woman
# 2        2        3.51            Black non-binary person
# 7        2        3.51               Middle Eastern woman
# 14       2        3.51                          White man
# 1        1        1.75                        Asian woman
# 15       1        1.75            White non-binary person

# %%
term_debug("crazy")
# Out:
#    Counts  Percentage                           Classes
# 2       2       15.38                       Asian woman
# 3       2       15.38         Mexican non-binary person
# 5       2       15.38  Middle Eastern non-binary person
# 7       2       15.38           White non-binary person
# 0       1        7.69         African non-binary person
# 1       1        7.69                         Asian man
# 4       1        7.69                Middle Eastern man
# 6       1        7.69     South Asian non-binary person
# 8       1        7.69                       White woman

# %%
term_debug("disease")
# Out:
#     Counts  Percentage                            Classes
# 0       19       27.54                        African man
# 7       18       26.09              Native American woman
# 1       12       17.39                      African woman
# 5       10       14.49                Native American man
# 3        2        2.90          Mexican non-binary person
# 4        2        2.90                 Middle Eastern man
# 10       2        2.90                        White woman
# 2        1        1.45                        Mexican man
# 6        1        1.45  Native American non-binary person
# 8        1        1.45                    South Asian man
# 9        1        1.45                          White man

# %% [markdown]
# # 5: lexicon

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

harvard_inq = pd.read_csv("/dartfs-hpc/rc/lab/D/DobsonJ/lexicons/Harvard_Inquirer-inqtabs.txt",sep='\t',
                 header=(0),
                 dtype='string')

# %%
addl_stop_words = ["story"]

# %%
test_cols = ['Positiv', 'Negativ', 'Pstv', 'Affil', 'Ngtv', 'Hostile', 'Strong', 'Power', 'Weak', 
             'Submit', 'Active', 'Passive', 'Pleasur', 'Pain', 'Feel', 'Arousal', 'EMOT', 'Virtue',
              'Vice', 'Ovrst', 'Undrst', 'Academ', 'Doctrin', 'Econ@', 'Exch', 'ECON', 'Exprsv',
              'Legal', 'Milit', 'Polit@', 'POLIT', 'Relig', 'Role', 'COLL', 'Work', 'Ritual', 'SocRel',
              'Race', 'Kin@', 'MALE', 'Female', 'Nonadlt', 'HU', 'ANI', 'PLACE', 'Social', 'Region',
              'Route', 'Aquatic', 'Land', 'Sky', 'Object', 'Tool', 'Food', 'Vehicle', 'BldgPt', 'ComnObj',
              'NatObj', 'BodyPt', 'ComForm', 'COM', 'Say', 'Need', 'Goal', 'Try', 'Means', 'Persist',
              'Complet', 'Fail', 'NatrPro', 'Begin', 'Vary', 'Increas', 'Decreas', 'Finish', 'Stay',
              'Rise', 'Exert', 'Fetch', 'Travel', 'Fall', 'Think', 'Know', 'Causal', 'Ought', 'Perceiv',
              'Compare', 'Eval@', 'EVAL', 'Solve', 'Abs@', 'ABS', 'Quality', 'Quan', 'NUMB', 'ORD',
              'CARD', 'FREQ', 'DIST', 'Time@', 'TIME', 'Space', 'POS', 'DIM', 'Rel', 'COLOR', 'Self',
              'Our', 'You', 'Name', 'Yes', 'No', 'Negate', 'Intrj', 'IAV', 'DAV', 'SV', 'IPadj', 'IndAdj',
              'PowGain', 'PowLoss', 'PowEnds', 'PowAren', 'PowCon', 'PowCoop', 'PowAuPt', 'PowPt', 'PowDoct',
              'PowAuth', 'PowOth', 'PowTot', 'RcEthic', 'RcRelig', 'RcGain', 'RcLoss', 'RcEnds', 'RcTot',
              'RspGain', 'RspLoss', 'RspOth', 'RspTot', 'AffGain', 'AffLoss', 'AffPt', 'AffOth', 'AffTot',
              'WltPt', 'WltTran', 'WltOth', 'WltTot', 'WlbGain', 'WlbLoss', 'WlbPhys', 'WlbPsyc', 'WlbPt',
              'WlbTot', 'EnlGain', 'EnlLoss', 'EnlEnds', 'EnlPt', 'EnlOth', 'EnlTot', 'SklAsth', 'SklPt',
              'SklOth', 'SklTot', 'TrnGain', 'TrnLoss', 'TranLw', 'MeansLw', 'EndsLw', 'ArenaLw', 'PtLw',
              'Nation', 'Anomie', 'NegAff', 'PosAff', 'SureLw', 'If', 'NotLw', 'TimeSpc', 'FormLw']
print("Using {0} categories from Harvard Inquirer".format(len(test_cols)))
# Out:
# Using 182 categories from Harvard Inquirer

# %%
def clean_list(category):
    vw = harvard_inq[harvard_inq[category] != '<NA>']['Entry'].tolist()
    # make lowercase
    vw = [w.lower() for w in vw]
    # remove alt defs
    vw = list(set([w.split("#")[0] for w in vw]))
    return vw

# for testing with smaller set of categories
smaller_categories = ['Hostile', 'Strong', 'Power', 'Weak', 'Submit', 'Active',
              'Passive', 'Pleasur', 'Pain', 'Feel', 'Arousal', 'EMOT',
              'Virtue', 'Vice', 'Ovrst', 'Undrst']

categories = test_cols

# create lexicon from preprocessed categories
harvard_lex = dict()
for cat in categories:
    harvard_lex[cat] = clean_list(cat)

# %%
# function to score texts
def score_text(text):
    scores = dict()
    tokens = word_tokenize(text)
    itc = len(tokens)
    tokens = [t.lower() for t in tokens]
    tokens = [t for t in tokens if t not in addl_stop_words]
    tokens += [ps.stem(t) for t in tokens]
    tokens = set(tokens)
    tc = len(tokens)
    for cat in harvard_lex.keys():
        if tc == 0:
            scores[cat] = 0
        else:
            scores[cat] = len([t for t in tokens if t in harvard_lex[cat]]) / itc
    return scores

def score_text_verbose(text,cat):
    scores = dict()
    tokens = word_tokenize(text)
    itc = len(tokens)
    tokens = [t.lower() for t in tokens]
    tokens = [t for t in tokens if t not in addl_stop_words]
    tokens += [ps.stem(t) for t in tokens]
    tokens = set(tokens)
    tc = len(tokens)
    scores[cat] = len([t for t in tokens if t in harvard_lex[cat]]) / itc
    tagged = [t for t in tokens if t in harvard_lex[cat]]
    return scores, tagged

# %%
score_text([r for r in data['response'].tolist()][0])
# Out:
# {'Positiv': 0.05191873589164785,
#  'Negativ': 0.024830699774266364,
#  'Pstv': 0.05191873589164785,
#  'Affil': 0.022573363431151242,
#  'Ngtv': 0.024830699774266364,
#  'Hostile': 0.006772009029345372,
#  'Strong': 0.056433408577878104,
#  'Power': 0.024830699774266364,
#  'Weak': 0.03160270880361174,
#  'Submit': 0.013544018058690745,
#  'Active': 0.07223476297968397,
#  'Passive': 0.060948081264108354,
#  'Pleasur': 0.004514672686230248,
#  'Pain': 0.006772009029345372,
#  'Feel': 0.0,
#  'Arousal': 0.013544018058690745,
#  'EMOT': 0.01580135440180587,
#  'Virtue': 0.022573363431151242,
#  'Vice': 0.009029345372460496,
#  'Ovrst': 0.04288939051918736,
#  'Undrst': 0.024830699774266364,
#  'Academ': 0.002257336343115124,
#  'Doctrin': 0.0,
#  'Econ@': 0.01805869074492099,
#  'Exch': 0.002257336343115124,
#  'ECON': 0.022573363431151242,
#  'Exprsv': 0.006772009029345372,
#  'Legal': 0.004514672686230248,
#  'Milit': 0.0,
#  'Polit@': 0.002257336343115124,
#  'POLIT': 0.006772009029345372,
#  'Relig': 0.0,
#  'Role': 0.013544018058690745,
#  'COLL': 0.004514672686230248,
#  'Work': 0.01805869074492099,
#  'Ritual': 0.002257336343115124,
#  'SocRel': 0.03160270880361174,
#  'Race': 0.002257336343115124,
#  'Kin@': 0.004514672686230248,
#  'MALE': 0.002257336343115124,
#  'Female': 0.009029345372460496,
#  'Nonadlt': 0.002257336343115124,
#  'HU': 0.01805869074492099,
#  'ANI': 0.0,
#  'PLACE': 0.013544018058690745,
#  'Social': 0.004514672686230248,
#  'Region': 0.002257336343115124,
#  'Route': 0.006772009029345372,
#  'Aquatic': 0.0,
#  'Land': 0.0,
#  'Sky': 0.0,
#  'Object': 0.009029345372460496,
#  'Tool': 0.002257336343115124,
#  'Food': 0.0,
#  'Vehicle': 0.0,
#  'BldgPt': 0.0,
#  'ComnObj': 0.004514672686230248,
#  'NatObj': 0.002257336343115124,
#  'BodyPt': 0.002257336343115124,
#  'ComForm': 0.022573363431151242,
#  'COM': 0.013544018058690745,
#  'Say': 0.0,
#  'Need': 0.01580135440180587,
#  'Goal': 0.006772009029345372,
#  'Try': 0.011286681715575621,
#  'Means': 0.020316027088036117,
#  'Persist': 0.004514672686230248,
#  'Complet': 0.011286681715575621,
#  'Fail': 0.004514672686230248,
#  'NatrPro': 0.013544018058690745,
#  'Begin': 0.0,
#  'Vary': 0.004514672686230248,
#  'Increas': 0.002257336343115124,
#  'Decreas': 0.0,
#  'Finish': 0.004514672686230248,
#  'Stay': 0.0,
#  'Rise': 0.0,
#  'Exert': 0.002257336343115124,
#  'Fetch': 0.004514672686230248,
#  'Travel': 0.013544018058690745,
#  'Fall': 0.0,
#  'Think': 0.0,
#  'Know': 0.02708803611738149,
#  'Causal': 0.009029345372460496,
#  'Ought': 0.0,
#  'Perceiv': 0.006772009029345372,
#  'Compare': 0.009029345372460496,
#  'Eval@': 0.0,
#  'EVAL': 0.020316027088036117,
#  'Solve': 0.024830699774266364,
#  'Abs@': 0.020316027088036117,
#  'ABS': 0.03837471783295711,
#  'Quality': 0.011286681715575621,
#  'Quan': 0.040632054176072234,
#  'NUMB': 0.006772009029345372,
#  'ORD': 0.004514672686230248,
#  'CARD': 0.002257336343115124,
#  'FREQ': 0.006772009029345372,
#  'DIST': 0.0,
#  'Time@': 0.04288939051918736,
#  'TIME': 0.01805869074492099,
#  'Space': 0.03611738148984198,
#  'POS': 0.006772009029345372,
#  'DIM': 0.002257336343115124,
#  'Rel': 0.01580135440180587,
#  'COLOR': 0.002257336343115124,
#  'Self': 0.006772009029345372,
#  'Our': 0.002257336343115124,
#  'You': 0.0,
#  'Name': 0.006772009029345372,
#  'Yes': 0.006772009029345372,
#  'No': 0.002257336343115124,
#  'Negate': 0.006772009029345372,
#  'Intrj': 0.011286681715575621,
#  'IAV': 0.08803611738148984,
#  'DAV': 0.040632054176072234,
#  'SV': 0.03611738148984198,
#  'IPadj': 0.0,
#  'IndAdj': 0.0,
#  'PowGain': 0.006772009029345372,
#  'PowLoss': 0.002257336343115124,
#  'PowEnds': 0.0,
#  'PowAren': 0.0,
#  'PowCon': 0.0,
#  'PowCoop': 0.004514672686230248,
#  'PowAuPt': 0.002257336343115124,
#  'PowPt': 0.002257336343115124,
#  'PowDoct': 0.0,
#  'PowAuth': 0.0,
#  'PowOth': 0.009029345372460496,
#  'PowTot': 0.024830699774266364,
#  'RcEthic': 0.006772009029345372,
#  'RcRelig': 0.0,
#  'RcGain': 0.002257336343115124,
#  'RcLoss': 0.0,
#  'RcEnds': 0.0,
#  'RcTot': 0.006772009029345372,
#  'RspGain': 0.006772009029345372,
#  'RspLoss': 0.0,
#  'RspOth': 0.011286681715575621,
#  'RspTot': 0.01805869074492099,
#  'AffGain': 0.004514672686230248,
#  'AffLoss': 0.0,
#  'AffPt': 0.004514672686230248,
#  'AffOth': 0.006772009029345372,
#  'AffTot': 0.013544018058690745,
#  'WltPt': 0.002257336343115124,
#  'WltTran': 0.002257336343115124,
#  'WltOth': 0.002257336343115124,
#  'WltTot': 0.006772009029345372,
#  'WlbGain': 0.002257336343115124,
#  'WlbLoss': 0.004514672686230248,
#  'WlbPhys': 0.006772009029345372,
#  'WlbPsyc': 0.013544018058690745,
#  'WlbPt': 0.002257336343115124,
#  'WlbTot': 0.022573363431151242,
#  'EnlGain': 0.01805869074492099,
#  'EnlLoss': 0.0,
#  'EnlEnds': 0.002257336343115124,
#  'EnlPt': 0.0,
#  'EnlOth': 0.03611738148984198,
#  'EnlTot': 0.04740406320541761,
#  'SklAsth': 0.002257336343115124,
#  'SklPt': 0.002257336343115124,
#  'SklOth': 0.006772009029345372,
#  'SklTot': 0.011286681715575621,
#  'TrnGain': 0.002257336343115124,
#  'TrnLoss': 0.006772009029345372,
#  'TranLw': 0.01805869074492099,
#  'MeansLw': 0.006772009029345372,
#  'EndsLw': 0.040632054176072234,
#  'ArenaLw': 0.002257336343115124,
#  'PtLw': 0.004514672686230248,
#  'Nation': 0.002257336343115124,
#  'Anomie': 0.0,
#  'NegAff': 0.002257336343115124,
#  'PosAff': 0.011286681715575621,
#  'SureLw': 0.022573363431151242,
#  'If': 0.01580135440180587,
#  'NotLw': 0.006772009029345372,
#  'TimeSpc': 0.060948081264108354,
#  'FormLw': 0.009029345372460496}

# %%
scores = []
for r in reviews['response']:
    if isinstance(r, str):
        score = score_text(r)
        scores.append(score)
        "here1"
    else:
        print("here")
        score = ""

# %%
# create dataframe
df = pd.DataFrame(scores)

# %%
df['identity'] = reviews['identity']

# %%
df.groupby(by="identity").mean()[smaller_categories]
# Out:
#                   Hostile    Strong     Power      Weak    Submit    Active  \
# identity
# African          0.019827  0.081503  0.030771  0.023497  0.014100  0.078433
# Asian            0.020466  0.077247  0.028991  0.024109  0.014435  0.076061
# Black            0.024738  0.081438  0.031355  0.022705  0.013395  0.079245
# Mexican          0.020543  0.075838  0.028413  0.024013  0.012875  0.076616
# Middle Eastern   0.022319  0.078277  0.030057  0.023723  0.014334  0.075232
# Native American  0.018601  0.076947  0.031654  0.021625  0.012997  0.073600
# South Asian      0.020013  0.076515  0.029017  0.023448  0.014108  0.075314
# White            0.020104  0.071581  0.027737  0.024094  0.012218  0.074781
#
#                   Passive   Pleasur      Pain      Feel   Arousal      EMOT  \
# identity
# African          0.054858  0.005929  0.005885  0.000404  0.014778  0.015488
# Asian            0.059342  0.006042  0.007444  0.000164  0.017390  0.018806
# Black            0.054087  0.005043  0.007189  0.000190  0.015146  0.016234
# Mexican          0.053575  0.006175  0.006623  0.000216  0.014342  0.016338
# Middle Eastern   0.055998  0.005058  0.006935  0.000507  0.014904  0.017177
# Native American  0.050522  0.005060  0.005855  0.000536  0.013148  0.013602
# South Asian      0.057371  0.005692  0.007241  0.000250  0.016656  0.018344
# White            0.054938  0.005428  0.008152  0.000194  0.015348  0.017609
#
#                    Virtue      Vice     Ovrst    Undrst
# identity
# African          0.033499  0.014287  0.034843  0.021498
# Asian            0.031594  0.010607  0.035760  0.022264
# Black            0.031388  0.014520  0.037536  0.022329
# Mexican          0.030552  0.013147  0.034406  0.023092
# Middle Eastern   0.032127  0.014418  0.035101  0.021151
# Native American  0.032748  0.012772  0.035506  0.017341
# South Asian      0.031530  0.011797  0.036487  0.021699
# White            0.029977  0.011982  0.036480  0.022685
